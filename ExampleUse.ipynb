# %%
import importlib
import FairValueGap
importlib.reload(FairValueGap)
from FairValueGap import SimpleFVG

# %%
fvgExample = SimpleFVG("SPY", "2010-01-01","2025-01-01", 1.5)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
fvgExample.get_data()
# Out:
# Price            Close        High         Low        Open  Daily Return  \
# Date
# 2010-01-05   86.254173   86.292130   85.662092   85.973318      0.002644
# 2010-01-06   86.314911   86.527452   86.102370   86.170684      0.000704
# 2010-01-07   86.679260   86.785531   85.912589   86.155494      0.004212
# 2010-01-08   86.967751   87.005707   86.276991   86.451576      0.003323
# 2010-01-11   87.089165   87.392792   86.717212   87.354841      0.001395
# ...                ...         ...         ...         ...           ...
# 2024-12-24  601.299988  601.340027  595.469971  596.059998      0.011054
# 2024-12-26  601.340027  602.479980  598.080017  599.500000      0.000067
# 2024-12-27  595.010010  597.780029  590.760010  597.539978     -0.010582
# 2024-12-30  588.219971  591.739990  584.409973  587.890015     -0.011477
# 2024-12-31  586.080017  590.640015  584.419983  589.909973     -0.003645
#
# Price       Daily Return Buy and Hold
# Date
# 2010-01-05                   1.002647
# 2010-01-06                   1.003353
# 2010-01-07                   1.007588
# 2010-01-08                   1.010942
# 2010-01-11                   1.012353
# ...                               ...
# 2024-12-24                   6.989710
# 2024-12-26                   6.990175
# 2024-12-27                   6.916593
# 2024-12-30                   6.837663
# 2024-12-31                   6.812788
#
# [3773 rows x 6 columns]

# %%
fvgExample.bullish_fvg_backtest(365)
#Alpha with 365 days and gap of 1.5 on SPY
#Alpha with 373 days and gap of 1.5 on NQ=F (Nasdaq Futures)
# Out:
# Bullish FVG found on these dates
# Price            gap
# Date
# 2010-09-02  1.922246
# 2010-11-05  1.663070
# 2010-12-02  1.509096
# 2011-09-27  2.104463
# 2011-10-24  1.539100
# ...
# Final Buy and Hold Return: 6.812787898890236
# Final Strategy Return: 7.433609970113366
# Final Buy and Hold Percent Return: 581.28%
# Final Strategy Percent Return: 643.36%
# Buy-and-Hold CAGR: 13.66%
# Strategy CAGR: 14.32%

# %%
fvgExample.bearish_fvg_backtest(3, 3)
# Out:
# Bearish FVG found on these dates
# Price            gap
# Date
# 2010-02-05  1.996406
# 2010-05-07  1.676858
# 2010-05-20  1.631085
# 2010-06-07  1.501547
# 2010-06-30  1.730746
# ...
# Final Buy and Hold Return: 6.812787898890236
# Final Strategy Return: 0.7585645593832854
# Final Buy and Hold Percent Return: 581.28%
# Final Strategy Percent Return: -24.14%
# Buy-and-Hold CAGR: 13.66%
# Strategy CAGR: -1.83%
